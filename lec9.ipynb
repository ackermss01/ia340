# %% [markdown]
# # Collect Tweets into MongoDB

# %% [markdown]
# ## Install Python libraries
#
# You may need to restart your Jupyter Notebook instance after installed those libraries.

# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.11.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.11.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0; extra == "srv" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from pymongo[srv]) (1.16.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install dnspython
# Out:
# Requirement already satisfied: dnspython in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.16.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install tweepy
# Out:
# Requirement already satisfied: tweepy in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (3.9.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tweepy) (2.22.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tweepy) (1.3.0)
# Requirement already satisfied: six>=1.10.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from tweepy) (1.14.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests[socks]>=2.11.1->tweepy) (2020.6.20)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests[socks]>=2.11.1->tweepy) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests[socks]>=2.11.1->tweepy) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests[socks]>=2.11.1->tweepy) (1.25.10)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests[socks]>=2.11.1->tweepy) (1.7.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (from requests-oauthlib>=0.7.0->tweepy) (3.1.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages (1.18.0)
# WARNING: You are using pip version 20.0.2; however, version 20.2.4 is available.
# You should consider upgrading via the '/home/ec2-user/anaconda3/envs/python3/bin/python -m pip install --upgrade pip' command.

# %% [markdown]
# ## Import Python libraries

# %%
import pymongo
from pymongo import MongoClient
import json
import tweepy
import twitter
from pprint import pprint
import configparser
import pandas as pd

# %% [markdown]
# ##  Load the Authorization Info

# %% [markdown]
# Save database connection info and API Keys in a config.ini file and use the configparse to load the authorization info.

# %%
config = configparser.ConfigParser()
config.read('config.ini')

CONSUMER_KEY      = config['mytwitter']['api_key']
CONSUMER_SECRET   = config['mytwitter']['api_secrete']
OAUTH_TOKEN       = config['mytwitter']['access_token']
OATH_TOKEN_SECRET = config['mytwitter']['access_secrete']

mongod_connect = config['mymongo']['connection']

# %% [markdown]
# ## Connect to the MongoDB Cluster

# %%
client = MongoClient(mongod_connect)
db = client.gp17 # use or create a database named gp17
tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-24-8e3670354c9f> in <module>
#       2 db = client.gp17 # use or create a database named gp17
#       3 tweet_collection = db.tweet_collection #use or create a collection named tweet_collection
# ----> 4 tweet_collection.create_index([("id", pymongo.ASCENDING)],unique = True) # make sure the collected tweets are unique
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in create_index(self, keys, session, **kwargs)
#    2057             cmd_options["maxTimeMS"] = kwargs.pop("maxTimeMS")
#    2058         index = IndexModel(keys, **kwargs)
# -> 2059         return self.__create_indexes([index], session, **cmd_options)[0]
#    2060
#    2061     def ensure_index(self, key_or_list, cache_for=300, **kwargs):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in __create_indexes(self, indexes, session, **kwargs)
#    1917         """
#    1918         names = []
# -> 1919         with self._socket_for_writes(session) as sock_info:
#    1920             supports_collations = sock_info.max_wire_version >= 5
#    1921             supports_quorum = sock_info.max_wire_version >= 9
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server, session, exhaust)
#    1245         with _MongoClientErrorHandler(self, server, session) as err_handler:
#    1246             with server.get_socket(
# -> 1247                     self.__all_credentials, checkout=exhaust) as sock_info:
#    1248                 err_handler.contribute_socket(sock_info)
#    1249                 if (self._encrypter and
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1223             listeners.publish_connection_check_out_started(self.address)
#    1224
# -> 1225         sock_info = self._get_socket(all_credentials)
#    1226
#    1227         if self.enabled_for_cmap:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1277                     if self._perished(sock_info):
#    1278                         sock_info = None
# -> 1279             sock_info.check_auth(all_credentials)
#    1280         except Exception:
#    1281             if sock_info:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     791
#     792             for credentials in cached - authset:
# --> 793                 self.authenticate(credentials)
#     794
#     795         # CMAP spec says to publish the ready event only after authenticating
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in authenticate(self, credentials)
#     808           - `credentials`: A MongoCredential.
#     809         """
# --> 810         auth.authenticate(credentials, self)
#     811         self.authset.add(credentials)
#     812         # negotiated_mechanisms are no longer needed.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     671     mechanism = credentials.mechanism
#     672     auth_func = _AUTH_MAP.get(mechanism)
# --> 673     auth_func(credentials, sock_info)
#     674
#     675
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     589             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     590         else:
# --> 591             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     592     elif sock_info.max_wire_version >= 3:
#     593         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
# --> 162                     parse_write_concern_error=parse_write_concern_error)
#     163     except Exception as exc:
#     164         if publish:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     166             msg = msg or "%s"
#     167             raise OperationFailure(msg % errmsg, code, response,
# --> 168                                    max_wire_version)
#     169
#     170
#
# OperationFailure: Authentication failed., full error: {'operationTime': Timestamp(1604510515, 1), 'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1604510515, 1), 'signature': {'hash': b'\x101\x02\x053\xf2&a5!V\x16\xa6\x99\xb0\x7f\xb6s\x81_', 'keyId': 6885054015411847171}}}

# %% [markdown]
# ## Use the Streaming API to Collect Tweets

# %% [markdown]
# Authorize the Stream API

# %%
stream_auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
stream_auth.set_access_token(OAUTH_TOKEN, OATH_TOKEN_SECRET)

strem_api = tweepy.API(stream_auth)

# %% [markdown]
# Define the query for the Stream API

# %%
track = ['election'] # define the keywords, tweets contain election

locations = [-78.9326449,38.4150904,-78.8816972,38.4450731] #defin the location, in Harrisonburg, VA

# %% [markdown]
# The collected tweets will contain 'election' <span style="color:red;font-weight:bold"> OR </span> are located in Harrisonburg, VA

# %%
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        print (status.id_str)
        try:
            tweet_collection.insert_one(status._json)
        except:
            pass
  
    def on_error(self, status_code):
        if status_code == 420:
            #returning False in on_data disconnects the stream
            return False
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = strem_api.auth, listener=myStreamListener)
myStream.filter(track=track)#  (locations = locations)   #Use either track or locations
# Out:
# 1324039712156184576
# 1324039712382701569
# 1324039712168939522
# 1324039712361844737
# 1324039712294735873
# 1324039712382877696
# 1324039712483405824
# 1324039712441597954
# 1324039712516894722
# 1324039712340889602
# 1324039712621953032
# 1324039712592457728
# 1324039712588267521
# 1324039712579952640
# 1324039711963439105
# 1324039712659615749
# 1324039712810635268
# 1324039712387092480
# 1324039712915574784
# 1324039712928006149
# 1324039712881823751
# 1324039712898777094
# 1324039712915529731
# 1324039712206704645
# 1324039713099902976
# 1324039713104125952
# 1324039713099931648
# 1324039712970067969
# 1324039713032949760
# 1324039712995184642
# 1324039712063983623
# 1324039713137872897
# 1324039712831610881
# 1324039713120940032
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     312         try:
# --> 313             return self.connection.recv_into(*args, **kwargs)
#     314         except OpenSSL.SSL.SysCallError as e:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1839             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1840         self._raise_ssl_error(self._ssl, result)
#    1841
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1645         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1646             raise WantReadError()
#    1647         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-11bc45f21258> in <module>
#      13 myStreamListener = MyStreamListener()
#      14 myStream = tweepy.Stream(auth = strem_api.auth, listener=myStreamListener)
# ---> 15 myStream.filter(track=track)#  (locations = locations)   #Use either track or locations
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     472             self.body['filter_level'] = filter_level.encode(encoding)
#     473         self.session.params = {'delimited': 'length'}
# --> 474         self._start(is_async)
#     475
#     476     def sitestream(self, follow, stall_warnings=False,
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     387             self._thread.start()
#     388         else:
# --> 389             self._run()
#     390
#     391     def on_closed(self, resp):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     287                     self.snooze_time = self.snooze_time_step
#     288                     self.listener.on_connect()
# --> 289                     self._read_loop(resp)
#     290             except (Timeout, ssl.SSLError) as exc:
#     291                 # This is still necessary, as a SSLError can actually be
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     337             length = 0
#     338             while not resp.raw.closed:
# --> 339                 line = buf.read_line()
#     340                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     341                 if not stripped_line:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     198             else:
#     199                 start = len(self._buffer)
# --> 200             self._buffer += self._stream.read(self._chunk_size)
#     201         return six.b('')
#     202
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in read(self, amt)
#     457             # Amount is given, implement using readinto
#     458             b = bytearray(amt)
# --> 459             n = self.readinto(b)
#     460             return memoryview(b)[:n].tobytes()
#     461         else:
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in readinto(self, b)
#     491
#     492         if self.chunked:
# --> 493             return self._readinto_chunked(b)
#     494
#     495         if self.length is not None:
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     586         try:
#     587             while True:
# --> 588                 chunk_left = self._get_chunk_left()
#     589                 if chunk_left is None:
#     590                     return total_bytes
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _get_chunk_left(self)
#     554                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     555             try:
# --> 556                 chunk_left = self._read_next_chunk_size()
#     557             except ValueError:
#     558                 raise IncompleteRead(b'')
#
# ~/anaconda3/envs/python3/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     514     def _read_next_chunk_size(self):
#     515         # Read the next chunk size from the file
# --> 516         line = self.fp.readline(_MAXLINE + 1)
#     517         if len(line) > _MAXLINE:
#     518             raise LineTooLong("chunk size")
#
# ~/anaconda3/envs/python3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     323                 raise
#     324         except OpenSSL.SSL.WantReadError:
# --> 325             if not util.wait_for_read(self.socket, self.socket.gettimeout()):
#     326                 raise timeout("The read operation timed out")
#     327             else:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(sock, timeout)
#     144     Returns True if the socket is readable, or False if the timeout expired.
#     145     """
# --> 146     return wait_for_socket(sock, read=True, timeout=timeout)
#     147
#     148
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/wait.py in poll_wait_for_socket(sock, read, write, timeout)
#     105         return poll_obj.poll(t)
#     106
# --> 107     return bool(_retry_on_intr(do_poll, timeout))
#     108
#     109
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/wait.py in _retry_on_intr(fn, timeout)
#      41     # Modern Python, that retries syscalls by default
#      42     def _retry_on_intr(fn, timeout):
# ---> 43         return fn(timeout)
#      44
#      45
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/urllib3/util/wait.py in do_poll(t)
#     103         if t is not None:
#     104             t *= 1000
# --> 105         return poll_obj.poll(t)
#     106
#     107     return bool(_retry_on_intr(do_poll, timeout))
#
# KeyboardInterrupt:

# %% [markdown]
# ## Use the REST API to Collect Tweets

# %% [markdown]
# Authorize the REST API

# %%
rest_auth = twitter.oauth.OAuth(OAUTH_TOKEN,OATH_TOKEN_SECRET,CONSUMER_KEY,CONSUMER_SECRET)
rest_api = twitter.Twitter(auth=rest_auth)

# %% [markdown]
# Define the query for the REST API

# %%
count = 100 #number of returned tweets, default and max is 100
geocode = "38.4392897,-78.9412224,50mi"  # defin the location, in Harrisonburg, VA
q = "election"                               #define the keywords, tweets contain election

# %% [markdown]
# The collected tweets will contain 'election' <span style="color:red;font-weight:bold"> AND </span> are located in Harrisonburg, VA

# %%
search_results = rest_api.search.tweets( count=count,q=q, geocode=geocode) #you can use both q and geocode
statuses = search_results["statuses"]
since_id_new = statuses[-1]['id']
for statuse in statuses:
    try:
        tweet_collection.insert_one(statuse)
        pprint(statuse['created_at'])# print the date of the collected tweets
    except:
        pass

# %% [markdown]
# Continue fetching early tweets with the same query.
# <p><span style="color:red;font-weight:bold">YOU WILL REACH YOUR RATE LIMIT VERY FAST</span></p>

# %%
since_id_old = 0
while(since_id_new != since_id_old):
    since_id_old = since_id_new
    search_results = rest_api.search.tweets( count=count,q=q,
                        geocode=geocode, max_id= since_id_new)
    statuses = search_results["statuses"]
    since_id_new = statuses[-1]['id']
    for statuse in statuses:
        try:
            tweet_collection.insert_one(statuse)
            pprint(statuse['created_at']) # print the date of the collected tweets
        except:
            pass

# %% [markdown]
# ## View the Collected Tweets

# %% [markdown]
# Print the number of tweets and unique twitter users

# %%
print(tweet_collection.estimated_document_count())# number of tweets collected

user_cursor = tweet_collection.distinct("user.id")
print (len(user_cursor)) # number of unique Twitter users
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-32-8f2dd3df7a72> in <module>
# ----> 1 print(tweet_collection.estimated_document_count())# number of tweets collected
#       2
#       3 user_cursor = tweet_collection.distinct("user.id")
#       4 print (len(user_cursor)) # number of unique Twitter users
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in estimated_document_count(self, **kwargs)
#    1702         cmd = SON([('count', self.__name)])
#    1703         cmd.update(kwargs)
# -> 1704         return self._count(cmd)
#    1705
#    1706     def count_documents(self, filter, session=None, **kwargs):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in _count(self, cmd, collation, session)
#    1663
#    1664         return self.__database.client._retryable_read(
# -> 1665             _cmd, self._read_preference_for(session), session)
#    1666
#    1667     def _aggregate_one_result(
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                     retryable = False
#    1464                 with self._slaveok_for_server(read_pref, server, session,
# -> 1465                                               exhaust=exhaust) as (sock_info,
#    1466                                                                    slave_ok):
#    1467                     if retrying and not retryable:
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _slaveok_for_server(self, read_preference, server, session, exhaust)
#    1307         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#    1308
# -> 1309         with self._get_socket(server, session, exhaust=exhaust) as sock_info:
#    1310             slave_ok = (single and not sock_info.is_mongos) or (
#    1311                 read_preference != ReadPreference.PRIMARY)
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server, session, exhaust)
#    1245         with _MongoClientErrorHandler(self, server, session) as err_handler:
#    1246             with server.get_socket(
# -> 1247                     self.__all_credentials, checkout=exhaust) as sock_info:
#    1248                 err_handler.contribute_socket(sock_info)
#    1249                 if (self._encrypter and
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1223             listeners.publish_connection_check_out_started(self.address)
#    1224
# -> 1225         sock_info = self._get_socket(all_credentials)
#    1226
#    1227         if self.enabled_for_cmap:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1277                     if self._perished(sock_info):
#    1278                         sock_info = None
# -> 1279             sock_info.check_auth(all_credentials)
#    1280         except Exception:
#    1281             if sock_info:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     791
#     792             for credentials in cached - authset:
# --> 793                 self.authenticate(credentials)
#     794
#     795         # CMAP spec says to publish the ready event only after authenticating
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in authenticate(self, credentials)
#     808           - `credentials`: A MongoCredential.
#     809         """
# --> 810         auth.authenticate(credentials, self)
#     811         self.authset.add(credentials)
#     812         # negotiated_mechanisms are no longer needed.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     671     mechanism = credentials.mechanism
#     672     auth_func = _AUTH_MAP.get(mechanism)
# --> 673     auth_func(credentials, sock_info)
#     674
#     675
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     589             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     590         else:
# --> 591             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     592     elif sock_info.max_wire_version >= 3:
#     593         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
# --> 162                     parse_write_concern_error=parse_write_concern_error)
#     163     except Exception as exc:
#     164         if publish:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     166             msg = msg or "%s"
#     167             raise OperationFailure(msg % errmsg, code, response,
# --> 168                                    max_wire_version)
#     169
#     170
#
# OperationFailure: Authentication failed., full error: {'operationTime': Timestamp(1604511255, 1), 'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1604511255, 1), 'signature': {'hash': b'b\xb6(\xa6.\xa2\xbfP\x1a\x1d\x0f\x11A\xbd\xd7q\x18\x14\xea\xf9', 'keyId': 6885054015411847171}}}

# %% [markdown]
# Create a text index and print the Tweets containing specific keywords.

# %%
tweet_collection.create_index([("text", pymongo.TEXT)], name='text_index', default_language='english') # create a text index
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-33-4494261c52ba> in <module>
# ----> 1 tweet_collection.create_index([("text", pymongo.TEXT)], name='text_index', default_language='english') # create a text index
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in create_index(self, keys, session, **kwargs)
#    2057             cmd_options["maxTimeMS"] = kwargs.pop("maxTimeMS")
#    2058         index = IndexModel(keys, **kwargs)
# -> 2059         return self.__create_indexes([index], session, **cmd_options)[0]
#    2060
#    2061     def ensure_index(self, key_or_list, cache_for=300, **kwargs):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/collection.py in __create_indexes(self, indexes, session, **kwargs)
#    1917         """
#    1918         names = []
# -> 1919         with self._socket_for_writes(session) as sock_info:
#    1920             supports_collations = sock_info.max_wire_version >= 5
#    1921             supports_quorum = sock_info.max_wire_version >= 9
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server, session, exhaust)
#    1245         with _MongoClientErrorHandler(self, server, session) as err_handler:
#    1246             with server.get_socket(
# -> 1247                     self.__all_credentials, checkout=exhaust) as sock_info:
#    1248                 err_handler.contribute_socket(sock_info)
#    1249                 if (self._encrypter and
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1223             listeners.publish_connection_check_out_started(self.address)
#    1224
# -> 1225         sock_info = self._get_socket(all_credentials)
#    1226
#    1227         if self.enabled_for_cmap:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1277                     if self._perished(sock_info):
#    1278                         sock_info = None
# -> 1279             sock_info.check_auth(all_credentials)
#    1280         except Exception:
#    1281             if sock_info:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     791
#     792             for credentials in cached - authset:
# --> 793                 self.authenticate(credentials)
#     794
#     795         # CMAP spec says to publish the ready event only after authenticating
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in authenticate(self, credentials)
#     808           - `credentials`: A MongoCredential.
#     809         """
# --> 810         auth.authenticate(credentials, self)
#     811         self.authset.add(credentials)
#     812         # negotiated_mechanisms are no longer needed.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     671     mechanism = credentials.mechanism
#     672     auth_func = _AUTH_MAP.get(mechanism)
# --> 673     auth_func(credentials, sock_info)
#     674
#     675
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     589             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     590         else:
# --> 591             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     592     elif sock_info.max_wire_version >= 3:
#     593         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
# --> 162                     parse_write_concern_error=parse_write_concern_error)
#     163     except Exception as exc:
#     164         if publish:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     166             msg = msg or "%s"
#     167             raise OperationFailure(msg % errmsg, code, response,
# --> 168                                    max_wire_version)
#     169
#     170
#
# OperationFailure: Authentication failed., full error: {'operationTime': Timestamp(1604511265, 1), 'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1604511265, 1), 'signature': {'hash': b'\x07\x12)u5\xf1\xfcj\xdb\xd5\xdc\xe3\xc0\xbf\xb4\xc81\xf6Za', 'keyId': 6885054015411847171}}}

# %% [markdown]
# Create a cursor to query tweets with the created index

# %%
tweet_cursor = tweet_collection.find({"$text": {"$search": "vote"}}) # return tweets contain vote

# %% [markdown]
# Use pprint to display tweets

# %%
for document in tweet_cursor[0:10]: # display the first 10 tweets from the query
    try:
        print ('----')
#         pprint (document) # use pprint to print the entire tweet document
   
        print ('name:', document["user"]["name"]) # user name
        print ('text:', document["text"])         # tweets
    except:
        print ("***error in encoding")
        pass
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-35-cb7ce609eb7f> in <module>
# ----> 1 for document in tweet_cursor[0:10]: # display the first 10 tweets from the query
#       2     try:
#       3         print ('----')
#       4 #         pprint (document) # use pprint to print the entire tweet document
#       5
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1122                                   self.__collection.database.client,
#    1123                                   self.__allow_disk_use)
# -> 1124             self.__send_message(q)
#    1125         elif self.__id:  # Get More
#    1126             if self.__limit:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     999             response = client._run_operation_with_response(
#    1000                 operation, self._unpack_response, exhaust=self.__exhaust,
# -> 1001                 address=self.__address)
#    1002         except OperationFailure:
#    1003             self.__killed = True
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1370             address=address,
#    1371             retryable=isinstance(operation, message._Query),
# -> 1372             exhaust=exhaust)
#    1373
#    1374     def _retry_with_session(self, retryable, func, session, bulk):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                     retryable = False
#    1464                 with self._slaveok_for_server(read_pref, server, session,
# -> 1465                                               exhaust=exhaust) as (sock_info,
#    1466                                                                    slave_ok):
#    1467                     if retrying and not retryable:
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _slaveok_for_server(self, read_preference, server, session, exhaust)
#    1307         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#    1308
# -> 1309         with self._get_socket(server, session, exhaust=exhaust) as sock_info:
#    1310             slave_ok = (single and not sock_info.is_mongos) or (
#    1311                 read_preference != ReadPreference.PRIMARY)
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server, session, exhaust)
#    1245         with _MongoClientErrorHandler(self, server, session) as err_handler:
#    1246             with server.get_socket(
# -> 1247                     self.__all_credentials, checkout=exhaust) as sock_info:
#    1248                 err_handler.contribute_socket(sock_info)
#    1249                 if (self._encrypter and
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1223             listeners.publish_connection_check_out_started(self.address)
#    1224
# -> 1225         sock_info = self._get_socket(all_credentials)
#    1226
#    1227         if self.enabled_for_cmap:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1277                     if self._perished(sock_info):
#    1278                         sock_info = None
# -> 1279             sock_info.check_auth(all_credentials)
#    1280         except Exception:
#    1281             if sock_info:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     791
#     792             for credentials in cached - authset:
# --> 793                 self.authenticate(credentials)
#     794
#     795         # CMAP spec says to publish the ready event only after authenticating
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in authenticate(self, credentials)
#     808           - `credentials`: A MongoCredential.
#     809         """
# --> 810         auth.authenticate(credentials, self)
#     811         self.authset.add(credentials)
#     812         # negotiated_mechanisms are no longer needed.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     671     mechanism = credentials.mechanism
#     672     auth_func = _AUTH_MAP.get(mechanism)
# --> 673     auth_func(credentials, sock_info)
#     674
#     675
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     589             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     590         else:
# --> 591             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     592     elif sock_info.max_wire_version >= 3:
#     593         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
# --> 162                     parse_write_concern_error=parse_write_concern_error)
#     163     except Exception as exc:
#     164         if publish:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     166             msg = msg or "%s"
#     167             raise OperationFailure(msg % errmsg, code, response,
# --> 168                                    max_wire_version)
#     169
#     170
#
# OperationFailure: Authentication failed., full error: {'operationTime': Timestamp(1604511295, 1), 'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1604511295, 1), 'signature': {'hash': b'0\x9f\x93x\xd2^#.B\xc7\x9d>ZC\t\x02\x88-\x11x', 'keyId': 6885054015411847171}}}

# %%
tweet_cursor = tweet_collection.find({"$text": {"$search": "vote"}}) # return tweets contain vote

# %% [markdown]
# Use pandas to display tweets

# %%
tweet_df = pd.DataFrame(list(tweet_cursor ))
tweet_df[:10] #display the first 10 tweets
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-37-2415da3da867> in <module>
# ----> 1 tweet_df = pd.DataFrame(list(tweet_cursor ))
#       2 tweet_df[:10] #display the first 10 tweets
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in _refresh(self)
#    1122                                   self.__collection.database.client,
#    1123                                   self.__allow_disk_use)
# -> 1124             self.__send_message(q)
#    1125         elif self.__id:  # Get More
#    1126             if self.__limit:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/cursor.py in __send_message(self, operation)
#     999             response = client._run_operation_with_response(
#    1000                 operation, self._unpack_response, exhaust=self.__exhaust,
# -> 1001                 address=self.__address)
#    1002         except OperationFailure:
#    1003             self.__killed = True
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1370             address=address,
#    1371             retryable=isinstance(operation, message._Query),
# -> 1372             exhaust=exhaust)
#    1373
#    1374     def _retry_with_session(self, retryable, func, session, bulk):
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1463                     retryable = False
#    1464                 with self._slaveok_for_server(read_pref, server, session,
# -> 1465                                               exhaust=exhaust) as (sock_info,
#    1466                                                                    slave_ok):
#    1467                     if retrying and not retryable:
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _slaveok_for_server(self, read_preference, server, session, exhaust)
#    1307         single = topology.description.topology_type == TOPOLOGY_TYPE.Single
#    1308
# -> 1309         with self._get_socket(server, session, exhaust=exhaust) as sock_info:
#    1310             slave_ok = (single and not sock_info.is_mongos) or (
#    1311                 read_preference != ReadPreference.PRIMARY)
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/mongo_client.py in _get_socket(self, server, session, exhaust)
#    1245         with _MongoClientErrorHandler(self, server, session) as err_handler:
#    1246             with server.get_socket(
# -> 1247                     self.__all_credentials, checkout=exhaust) as sock_info:
#    1248                 err_handler.contribute_socket(sock_info)
#    1249                 if (self._encrypter and
#
# ~/anaconda3/envs/python3/lib/python3.6/contextlib.py in __enter__(self)
#      79     def __enter__(self):
#      80         try:
# ---> 81             return next(self.gen)
#      82         except StopIteration:
#      83             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in get_socket(self, all_credentials, checkout)
#    1223             listeners.publish_connection_check_out_started(self.address)
#    1224
# -> 1225         sock_info = self._get_socket(all_credentials)
#    1226
#    1227         if self.enabled_for_cmap:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in _get_socket(self, all_credentials)
#    1277                     if self._perished(sock_info):
#    1278                         sock_info = None
# -> 1279             sock_info.check_auth(all_credentials)
#    1280         except Exception:
#    1281             if sock_info:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in check_auth(self, all_credentials)
#     791
#     792             for credentials in cached - authset:
# --> 793                 self.authenticate(credentials)
#     794
#     795         # CMAP spec says to publish the ready event only after authenticating
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in authenticate(self, credentials)
#     808           - `credentials`: A MongoCredential.
#     809         """
# --> 810         auth.authenticate(credentials, self)
#     811         self.authset.add(credentials)
#     812         # negotiated_mechanisms are no longer needed.
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in authenticate(credentials, sock_info)
#     671     mechanism = credentials.mechanism
#     672     auth_func = _AUTH_MAP.get(mechanism)
# --> 673     auth_func(credentials, sock_info)
#     674
#     675
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_default(credentials, sock_info)
#     589             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-256')
#     590         else:
# --> 591             return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#     592     elif sock_info.max_wire_version >= 3:
#     593         return _authenticate_scram(credentials, sock_info, 'SCRAM-SHA-1')
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/auth.py in _authenticate_scram(credentials, sock_info, mechanism)
#     293         nonce, first_bare, cmd = _authenticate_scram_start(
#     294             credentials, mechanism)
# --> 295         res = sock_info.command(source, cmd)
#     296
#     297     server_first = res['payload']
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/pool.py in command(self, dbname, spec, slave_ok, read_preference, codec_options, check, allowable_errors, check_keys, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     692                            unacknowledged=unacknowledged,
#     693                            user_fields=user_fields,
# --> 694                            exhaust_allowed=exhaust_allowed)
#     695         except OperationFailure:
#     696             raise
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/network.py in command(sock_info, dbname, spec, slave_ok, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, check_keys, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed)
#     160                     response_doc, sock_info.max_wire_version, None,
#     161                     allowable_errors,
# --> 162                     parse_write_concern_error=parse_write_concern_error)
#     163     except Exception as exc:
#     164         if publish:
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/pymongo/helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     166             msg = msg or "%s"
#     167             raise OperationFailure(msg % errmsg, code, response,
# --> 168                                    max_wire_version)
#     169
#     170
#
# OperationFailure: Authentication failed., full error: {'operationTime': Timestamp(1604511305, 1), 'ok': 0.0, 'errmsg': 'Authentication failed.', 'code': 18, 'codeName': 'AuthenticationFailed', '$clusterTime': {'clusterTime': Timestamp(1604511305, 1), 'signature': {'hash': b'`F^\xdf\x96A\x80UA\x80Y\xf5Q\x93\x8d\xc54\x8f\xb7\xd2', 'keyId': 6885054015411847171}}}

# %%
tweet_df["favorite_count"].hist() # create a histogram show the favorite count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-8c78f95863e1> in <module>
# ----> 1 tweet_df["favorite_count"].hist() # create a histogram show the favorite count
#
# NameError: name 'tweet_df' is not defined
